# %%
# Import the dependencies
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
#create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# create a list for holding the cities
cities = []
#identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 712

# %%
# imort the requests library
import requests

# import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Import the time library 
import time

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging
print('Beginning Data Retrieval      ')
print('------------------------------')

# create counters
record_count = 1
set_count = 1

# loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in set of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
        time.sleep(60)
        
    #create endpoint URL with each city
    city_url = url + '&q=' + city.replace(" ", "+")
    
    # log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # Add 1 to the record count
    record_count +=1
    
# Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
# If an error is experienced, skip the city.
    except:
        print('City not found. Skipping...')
        pass

# Indicate that Data Loading is complete
print('------------------------------')
print('Data Retrieval Complete       ')
print('------------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | fort dodge
# Processing Record 2 of Set 1 | babaeski
# Processing Record 3 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | nouadhibou
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | fernley
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | meulaboh
# Processing Record 15 of Set 1 | chicama
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | victoria
# Processing Record 23 of Set 1 | nebbi
# Processing Record 24 of Set 1 | walvis bay
# Processing Record 25 of Set 1 | hovd
# Processing Record 26 of Set 1 | amapa
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | half moon bay
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | longyearbyen
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | monrovia
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | bathsheba
# Processing Record 39 of Set 1 | kaitangata
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | burica
# City not found. Skipping...
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | simpang
# Processing Record 44 of Set 1 | geraldton
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | gamba
# Processing Record 47 of Set 1 | provideniya
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | sirfa
# City not found. Skipping...
# Processing Record 50 of Set 1 | vieste
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | fort nelson
# Processing Record 4 of Set 2 | kizukuri
# Processing Record 5 of Set 2 | samarai
# Processing Record 6 of Set 2 | zweibrucken
# Processing Record 7 of Set 2 | boulder
# Processing Record 8 of Set 2 | alice springs
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | san rafael
# Processing Record 11 of Set 2 | saldanha
# Processing Record 12 of Set 2 | nanortalik
# Processing Record 13 of Set 2 | batemans bay
# Processing Record 14 of Set 2 | ipixuna
# Processing Record 15 of Set 2 | ilulissat
# Processing Record 16 of Set 2 | nome
# Processing Record 17 of Set 2 | camalu
# Processing Record 18 of Set 2 | xintai
# Processing Record 19 of Set 2 | port elizabeth
# Processing Record 20 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 2 | podgornoye
# Processing Record 22 of Set 2 | cerrito
# Processing Record 23 of Set 2 | mecca
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | ilebo
# Processing Record 26 of Set 2 | port hardy
# Processing Record 27 of Set 2 | naliya
# Processing Record 28 of Set 2 | srednekolymsk
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 31 of Set 2 | chipinge
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | charters towers
# Processing Record 34 of Set 2 | saint-augustin
# Processing Record 35 of Set 2 | katherine
# Processing Record 36 of Set 2 | ostrovnoy
# Processing Record 37 of Set 2 | buwenge
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | alta floresta
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | thinadhoo
# Processing Record 42 of Set 2 | paamiut
# Processing Record 43 of Set 2 | tuatapere
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | lagoa
# Processing Record 46 of Set 2 | la orilla
# Processing Record 47 of Set 2 | yungay
# Processing Record 48 of Set 2 | sioux lookout
# Processing Record 49 of Set 2 | rawson
# Processing Record 50 of Set 2 | cauquenes
# Processing Record 1 of Set 3 | cap malheureux
# Processing Record 2 of Set 3 | sao joao da barra
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | rocha
# Processing Record 5 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 3 | houma
# Processing Record 7 of Set 3 | port alfred
# Processing Record 8 of Set 3 | busselton
# Processing Record 9 of Set 3 | wanaka
# Processing Record 10 of Set 3 | tekeli
# Processing Record 11 of Set 3 | klyuchi
# Processing Record 12 of Set 3 | dunedin
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | marzuq
# Processing Record 15 of Set 3 | gualeguaychu
# Processing Record 16 of Set 3 | port blair
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | aulnoye-aymeries
# Processing Record 19 of Set 3 | takoradi
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | hamilton
# Processing Record 23 of Set 3 | ushuaia
# Processing Record 24 of Set 3 | talnakh
# Processing Record 25 of Set 3 | pietarsaari
# Processing Record 26 of Set 3 | staryy nadym
# Processing Record 27 of Set 3 | cabo san lucas
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | kirakira
# Processing Record 30 of Set 3 | shawnee
# Processing Record 31 of Set 3 | lavrentiya
# Processing Record 32 of Set 3 | tura
# Processing Record 33 of Set 3 | jiazi
# Processing Record 34 of Set 3 | bambanglipuro
# Processing Record 35 of Set 3 | san patricio
# Processing Record 36 of Set 3 | arlit
# Processing Record 37 of Set 3 | elat
# Processing Record 38 of Set 3 | raahe
# Processing Record 39 of Set 3 | ngawi
# Processing Record 40 of Set 3 | cayenne
# Processing Record 41 of Set 3 | bosaso
# Processing Record 42 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 3 | linxia
# Processing Record 44 of Set 3 | laguna
# Processing Record 45 of Set 3 | serra
# Processing Record 46 of Set 3 | komsomolskiy
# Processing Record 47 of Set 3 | jacareacanga
# Processing Record 48 of Set 3 | bengkulu
# Processing Record 49 of Set 3 | caravelas
# Processing Record 50 of Set 3 | adrar
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | loreto
# Processing Record 4 of Set 4 | avarua
# Processing Record 5 of Set 4 | kavieng
# Processing Record 6 of Set 4 | berlevag
# Processing Record 7 of Set 4 | lonevag
# Processing Record 8 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | san quintin
# Processing Record 11 of Set 4 | teguise
# Processing Record 12 of Set 4 | cockburn town
# Processing Record 13 of Set 4 | babati
# Processing Record 14 of Set 4 | burgos
# Processing Record 15 of Set 4 | iqaluit
# Processing Record 16 of Set 4 | marovoay
# Processing Record 17 of Set 4 | serebryansk
# Processing Record 18 of Set 4 | mombaca
# Processing Record 19 of Set 4 | lompoc
# Processing Record 20 of Set 4 | prince rupert
# Processing Record 21 of Set 4 | luganville
# Processing Record 22 of Set 4 | qixia
# Processing Record 23 of Set 4 | saint george
# Processing Record 24 of Set 4 | porto novo
# Processing Record 25 of Set 4 | tautira
# Processing Record 26 of Set 4 | san angelo
# Processing Record 27 of Set 4 | santa maria da vitoria
# Processing Record 28 of Set 4 | norman wells
# Processing Record 29 of Set 4 | pak thong chai
# Processing Record 30 of Set 4 | port augusta
# Processing Record 31 of Set 4 | namtsy
# Processing Record 32 of Set 4 | isangel
# Processing Record 33 of Set 4 | lebu
# Processing Record 34 of Set 4 | kautokeino
# Processing Record 35 of Set 4 | narsaq
# Processing Record 36 of Set 4 | puerto ayora
# Processing Record 37 of Set 4 | grinnell
# Processing Record 38 of Set 4 | ajdabiya
# Processing Record 39 of Set 4 | plettenberg bay
# Processing Record 40 of Set 4 | bambous virieux
# Processing Record 41 of Set 4 | tuy hoa
# Processing Record 42 of Set 4 | malente
# Processing Record 43 of Set 4 | miraflores
# Processing Record 44 of Set 4 | sakakah
# Processing Record 45 of Set 4 | buchanan
# Processing Record 46 of Set 4 | yar-sale
# Processing Record 47 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 4 | mozarlandia
# Processing Record 49 of Set 4 | mayor pablo lagerenza
# Processing Record 50 of Set 4 | vao
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | khatanga
# Processing Record 3 of Set 5 | boulsa
# Processing Record 4 of Set 5 | chokurdakh
# Processing Record 5 of Set 5 | ust-ilimsk
# Processing Record 6 of Set 5 | sao filipe
# Processing Record 7 of Set 5 | saint-leu
# Processing Record 8 of Set 5 | clyde river
# Processing Record 9 of Set 5 | guerrero negro
# Processing Record 10 of Set 5 | varkkallai
# Processing Record 11 of Set 5 | oranjestad
# Processing Record 12 of Set 5 | coquimbo
# Processing Record 13 of Set 5 | haines junction
# Processing Record 14 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 5 | huilong
# Processing Record 16 of Set 5 | noumea
# Processing Record 17 of Set 5 | cuamba
# Processing Record 18 of Set 5 | mayo
# Processing Record 19 of Set 5 | mehamn
# Processing Record 20 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 5 | suntar
# Processing Record 22 of Set 5 | anadyr
# Processing Record 23 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 5 | panalingaan
# Processing Record 26 of Set 5 | tessalit
# Processing Record 27 of Set 5 | zahirabad
# Processing Record 28 of Set 5 | flin flon
# Processing Record 29 of Set 5 | kleck
# City not found. Skipping...
# Processing Record 30 of Set 5 | stornoway
# Processing Record 31 of Set 5 | maceio
# Processing Record 32 of Set 5 | leningradskiy
# Processing Record 33 of Set 5 | mogadishu
# Processing Record 34 of Set 5 | camacha
# Processing Record 35 of Set 5 | baykit
# Processing Record 36 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 5 | matara
# Processing Record 38 of Set 5 | jutai
# Processing Record 39 of Set 5 | verkhnyaya inta
# Processing Record 40 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 5 | sur
# Processing Record 42 of Set 5 | tiksi
# Processing Record 43 of Set 5 | bismarck
# Processing Record 44 of Set 5 | livramento
# Processing Record 45 of Set 5 | ejido
# Processing Record 46 of Set 5 | aybak
# City not found. Skipping...
# Processing Record 47 of Set 5 | majene
# Processing Record 48 of Set 5 | barzas
# Processing Record 49 of Set 5 | sinnamary
# Processing Record 50 of Set 5 | antigonish
# Processing Record 1 of Set 6 | katobu
# Processing Record 2 of Set 6 | nova prata
# Processing Record 3 of Set 6 | namibe
# Processing Record 4 of Set 6 | katsuura
# Processing Record 5 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 6 | saint-philippe
# Processing Record 7 of Set 6 | conde
# Processing Record 8 of Set 6 | los llanos de aridane
# Processing Record 9 of Set 6 | medicine hat
# Processing Record 10 of Set 6 | mount isa
# Processing Record 11 of Set 6 | severo-kurilsk
# Processing Record 12 of Set 6 | trebisacce
# Processing Record 13 of Set 6 | lorengau
# Processing Record 14 of Set 6 | portland
# Processing Record 15 of Set 6 | kurchum
# Processing Record 16 of Set 6 | vanimo
# Processing Record 17 of Set 6 | dingle
# Processing Record 18 of Set 6 | tiebissou
# Processing Record 19 of Set 6 | labuhan
# Processing Record 20 of Set 6 | ahuimanu
# Processing Record 21 of Set 6 | college
# Processing Record 22 of Set 6 | kidal
# Processing Record 23 of Set 6 | faya
# Processing Record 24 of Set 6 | valjala
# City not found. Skipping...
# Processing Record 25 of Set 6 | ewa beach
# Processing Record 26 of Set 6 | natal
# Processing Record 27 of Set 6 | inongo
# Processing Record 28 of Set 6 | avera
# Processing Record 29 of Set 6 | galle
# Processing Record 30 of Set 6 | naze
# Processing Record 31 of Set 6 | winnemucca
# Processing Record 32 of Set 6 | vrangel
# Processing Record 33 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 6 | touros
# Processing Record 35 of Set 6 | santa lucia
# Processing Record 36 of Set 6 | batagay-alyta
# Processing Record 37 of Set 6 | korla
# Processing Record 38 of Set 6 | batamshinskiy
# Processing Record 39 of Set 6 | tromso
# Processing Record 40 of Set 6 | marsa matruh
# Processing Record 41 of Set 6 | hay river
# Processing Record 42 of Set 6 | hobyo
# Processing Record 43 of Set 6 | san cristobal
# Processing Record 44 of Set 6 | rundu
# Processing Record 45 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 6 | viedma
# Processing Record 47 of Set 6 | angleton
# Processing Record 48 of Set 6 | enshi
# Processing Record 49 of Set 6 | brae
# Processing Record 50 of Set 6 | cidreira
# Processing Record 1 of Set 7 | shelburne
# Processing Record 2 of Set 7 | sungaipenuh
# Processing Record 3 of Set 7 | salalah
# Processing Record 4 of Set 7 | esperance
# Processing Record 5 of Set 7 | vallenar
# Processing Record 6 of Set 7 | tucuman
# Processing Record 7 of Set 7 | kavaratti
# Processing Record 8 of Set 7 | kununurra
# Processing Record 9 of Set 7 | sao lourenco do sul
# Processing Record 10 of Set 7 | taoudenni
# Processing Record 11 of Set 7 | launceston
# Processing Record 12 of Set 7 | taltal
# Processing Record 13 of Set 7 | kodinsk
# Processing Record 14 of Set 7 | muros
# Processing Record 15 of Set 7 | tottori
# Processing Record 16 of Set 7 | high rock
# Processing Record 17 of Set 7 | cahors
# Processing Record 18 of Set 7 | mizdah
# Processing Record 19 of Set 7 | monte gordo
# Processing Record 20 of Set 7 | gotsu
# Processing Record 21 of Set 7 | kruisfontein
# Processing Record 22 of Set 7 | ancud
# Processing Record 23 of Set 7 | koslan
# Processing Record 24 of Set 7 | rio grande
# Processing Record 25 of Set 7 | beloha
# Processing Record 26 of Set 7 | faanui
# Processing Record 27 of Set 7 | sabang
# Processing Record 28 of Set 7 | hanko
# Processing Record 29 of Set 7 | autun
# Processing Record 30 of Set 7 | husavik
# Processing Record 31 of Set 7 | mazamari
# Processing Record 32 of Set 7 | morondava
# Processing Record 33 of Set 7 | cogoleto
# Processing Record 34 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 35 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 37 of Set 7 | rio gallegos
# Processing Record 38 of Set 7 | fallon
# Processing Record 39 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 40 of Set 7 | huntsville
# Processing Record 41 of Set 7 | tuktoyaktuk
# Processing Record 42 of Set 7 | kutahya
# Processing Record 43 of Set 7 | coihaique
# Processing Record 44 of Set 7 | yumen
# Processing Record 45 of Set 7 | beringovskiy
# Processing Record 46 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 7 | ossora
# Processing Record 48 of Set 7 | akot
# Processing Record 49 of Set 7 | nelson bay
# Processing Record 50 of Set 7 | calama
# Processing Record 1 of Set 8 | bom sucesso
# Processing Record 2 of Set 8 | birin
# Processing Record 3 of Set 8 | la romana
# Processing Record 4 of Set 8 | coahuayana
# Processing Record 5 of Set 8 | sorland
# Processing Record 6 of Set 8 | kangaba
# Processing Record 7 of Set 8 | yamada
# Processing Record 8 of Set 8 | alofi
# Processing Record 9 of Set 8 | koumra
# Processing Record 10 of Set 8 | moroto
# Processing Record 11 of Set 8 | yulara
# Processing Record 12 of Set 8 | zalantun
# Processing Record 13 of Set 8 | rehoboth
# Processing Record 14 of Set 8 | suez
# Processing Record 15 of Set 8 | mountain home
# Processing Record 16 of Set 8 | codrington
# Processing Record 17 of Set 8 | matagami
# Processing Record 18 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 8 | hasaki
# Processing Record 20 of Set 8 | aklavik
# Processing Record 21 of Set 8 | kieta
# Processing Record 22 of Set 8 | turgutlu
# Processing Record 23 of Set 8 | vila franca do campo
# Processing Record 24 of Set 8 | vestmannaeyjar
# Processing Record 25 of Set 8 | santa rita
# Processing Record 26 of Set 8 | kolondieba
# Processing Record 27 of Set 8 | westport
# Processing Record 28 of Set 8 | aksu
# Processing Record 29 of Set 8 | palmer
# Processing Record 30 of Set 8 | raudeberg
# Processing Record 31 of Set 8 | mahanoro
# Processing Record 32 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 8 | najran
# Processing Record 34 of Set 8 | sola
# Processing Record 35 of Set 8 | mwanza
# Processing Record 36 of Set 8 | weener
# Processing Record 37 of Set 8 | gravdal
# Processing Record 38 of Set 8 | shitanjing
# Processing Record 39 of Set 8 | pisco
# Processing Record 40 of Set 8 | ahipara
# Processing Record 41 of Set 8 | yongan
# Processing Record 42 of Set 8 | buin
# Processing Record 43 of Set 8 | sao sebastiao
# Processing Record 44 of Set 8 | gouyave
# Processing Record 45 of Set 8 | bandarbeyla
# Processing Record 46 of Set 8 | pangai
# Processing Record 47 of Set 8 | general pico
# Processing Record 48 of Set 8 | lerwick
# Processing Record 49 of Set 8 | dzhebariki-khaya
# Processing Record 50 of Set 8 | santiago
# Processing Record 1 of Set 9 | carahue
# Processing Record 2 of Set 9 | port-gentil
# Processing Record 3 of Set 9 | santa maria del oro
# Processing Record 4 of Set 9 | qasigiannguit
# Processing Record 5 of Set 9 | tukrah
# Processing Record 6 of Set 9 | granja
# Processing Record 7 of Set 9 | puerto escondido
# Processing Record 8 of Set 9 | cordeiro
# Processing Record 9 of Set 9 | dudinka
# Processing Record 10 of Set 9 | aykhal
# Processing Record 11 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 12 of Set 9 | warrington
# Processing Record 13 of Set 9 | nagua
# Processing Record 14 of Set 9 | mezen
# Processing Record 15 of Set 9 | flinders
# Processing Record 16 of Set 9 | santona
# Processing Record 17 of Set 9 | souillac
# Processing Record 18 of Set 9 | boiro
# Processing Record 19 of Set 9 | corinto
# Processing Record 20 of Set 9 | kachkanar
# Processing Record 21 of Set 9 | zhezkazgan
# Processing Record 22 of Set 9 | hofn
# Processing Record 23 of Set 9 | neijiang
# Processing Record 24 of Set 9 | oshnaviyeh
# Processing Record 25 of Set 9 | bonavista
# Processing Record 26 of Set 9 | erice
# Processing Record 27 of Set 9 | ojinaga
# Processing Record 28 of Set 9 | fairbanks
# Processing Record 29 of Set 9 | waingapu
# Processing Record 30 of Set 9 | san jose
# Processing Record 31 of Set 9 | zhanaozen
# Processing Record 32 of Set 9 | chulman
# Processing Record 33 of Set 9 | sayansk
# Processing Record 34 of Set 9 | qandala
# Processing Record 35 of Set 9 | teknaf
# Processing Record 36 of Set 9 | buon me thuot
# City not found. Skipping...
# Processing Record 37 of Set 9 | bardiyah
# Processing Record 38 of Set 9 | mawlaik
# Processing Record 39 of Set 9 | ayan
# Processing Record 40 of Set 9 | alugan
# Processing Record 41 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 9 | chilia veche
# Processing Record 43 of Set 9 | bud
# Processing Record 44 of Set 9 | haimen
# Processing Record 45 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 9 | la asuncion
# Processing Record 47 of Set 9 | somerset west
# Processing Record 48 of Set 9 | dalbandin
# Processing Record 49 of Set 9 | turukhansk
# Processing Record 50 of Set 9 | simao
# Processing Record 1 of Set 10 | lata
# Processing Record 2 of Set 10 | coachella
# Processing Record 3 of Set 10 | ribeira grande
# Processing Record 4 of Set 10 | estrella
# Processing Record 5 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 6 of Set 10 | kuloy
# Processing Record 7 of Set 10 | santa cruz
# Processing Record 8 of Set 10 | mehriz
# Processing Record 9 of Set 10 | cuajinicuilapa
# Processing Record 10 of Set 10 | sovetskiy
# Processing Record 11 of Set 10 | wajir
# Processing Record 12 of Set 10 | peniche
# Processing Record 13 of Set 10 | buritis
# Processing Record 14 of Set 10 | srandakan
# Processing Record 15 of Set 10 | pizarro
# Processing Record 16 of Set 10 | bilma
# Processing Record 17 of Set 10 | adana
# Processing Record 18 of Set 10 | vila velha
# Processing Record 19 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 10 | west plains
# Processing Record 21 of Set 10 | altamont
# Processing Record 22 of Set 10 | ibra
# Processing Record 23 of Set 10 | blythe
# Processing Record 24 of Set 10 | bavly
# Processing Record 25 of Set 10 | havre-saint-pierre
# Processing Record 26 of Set 10 | tanete
# Processing Record 27 of Set 10 | taungdwingyi
# Processing Record 28 of Set 10 | tecoanapa
# Processing Record 29 of Set 10 | nurota
# Processing Record 30 of Set 10 | airai
# Processing Record 31 of Set 10 | chittur
# Processing Record 32 of Set 10 | palatka
# Processing Record 33 of Set 10 | doba
# Processing Record 34 of Set 10 | aswan
# Processing Record 35 of Set 10 | galdar
# Processing Record 36 of Set 10 | port macquarie
# Processing Record 37 of Set 10 | pachino
# Processing Record 38 of Set 10 | kemijarvi
# Processing Record 39 of Set 10 | banda aceh
# Processing Record 40 of Set 10 | caohai
# Processing Record 41 of Set 10 | paragominas
# Processing Record 42 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 10 | bilibino
# Processing Record 44 of Set 10 | maragogi
# Processing Record 45 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 10 | laichingen
# Processing Record 47 of Set 10 | lavumisa
# Processing Record 48 of Set 10 | coihueco
# Processing Record 49 of Set 10 | eyl
# Processing Record 50 of Set 10 | piacabucu
# Processing Record 1 of Set 11 | asasa
# Processing Record 2 of Set 11 | pangnirtung
# Processing Record 3 of Set 11 | lamar
# Processing Record 4 of Set 11 | grand gaube
# Processing Record 5 of Set 11 | borogontsy
# Processing Record 6 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 7 of Set 11 | zambezi
# Processing Record 8 of Set 11 | dispur
# Processing Record 9 of Set 11 | valley city
# Processing Record 10 of Set 11 | rush
# Processing Record 11 of Set 11 | ennis
# Processing Record 12 of Set 11 | marabba
# Processing Record 13 of Set 11 | kholodnyy
# Processing Record 14 of Set 11 | sayyan
# Processing Record 15 of Set 11 | chengde
# Processing Record 16 of Set 11 | yushan
# Processing Record 17 of Set 11 | humboldt
# Processing Record 18 of Set 11 | presidencia roque saenz pena
# Processing Record 19 of Set 11 | havre
# Processing Record 20 of Set 11 | nanyamba
# Processing Record 21 of Set 11 | port hedland
# Processing Record 22 of Set 11 | nantucket
# Processing Record 23 of Set 11 | rudnya
# Processing Record 24 of Set 11 | quimperle
# Processing Record 25 of Set 11 | kyra
# Processing Record 26 of Set 11 | altamira
# Processing Record 27 of Set 11 | mirnyy
# Processing Record 28 of Set 11 | namatanai
# Processing Record 29 of Set 11 | carnot
# Processing Record 30 of Set 11 | gambiran
# Processing Record 31 of Set 11 | chara
# Processing Record 32 of Set 11 | kikwit
# Processing Record 33 of Set 11 | poum
# Processing Record 34 of Set 11 | lae
# Processing Record 35 of Set 11 | muisne
# Processing Record 36 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 11 | bulgan
# Processing Record 38 of Set 11 | kudahuvadhoo
# Processing Record 39 of Set 11 | krabi
# Processing Record 40 of Set 11 | lokosovo
# Processing Record 41 of Set 11 | verkhoyansk
# Processing Record 42 of Set 11 | upata
# Processing Record 43 of Set 11 | sawtell
# Processing Record 44 of Set 11 | kismayo
# Processing Record 45 of Set 11 | gazojak
# Processing Record 46 of Set 11 | moose factory
# Processing Record 47 of Set 11 | saint-francois
# Processing Record 48 of Set 11 | mandalgovi
# Processing Record 49 of Set 11 | kilindoni
# Processing Record 50 of Set 11 | la palma
# Processing Record 1 of Set 12 | altay
# Processing Record 2 of Set 12 | praia
# Processing Record 3 of Set 12 | les cayes
# Processing Record 4 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 5 of Set 12 | fortuna
# Processing Record 6 of Set 12 | belawan
# Processing Record 7 of Set 12 | doha
# Processing Record 8 of Set 12 | vanino
# Processing Record 9 of Set 12 | wasilla
# Processing Record 10 of Set 12 | jumla
# Processing Record 11 of Set 12 | tilichiki
# Processing Record 12 of Set 12 | swift current
# Processing Record 13 of Set 12 | tahlequah
# Processing Record 14 of Set 12 | kamakwie
# Processing Record 15 of Set 12 | ponta delgada
# Processing Record 16 of Set 12 | maniitsoq
# Processing Record 17 of Set 12 | stranda
# Processing Record 18 of Set 12 | lokomotivnyy
# Processing Record 19 of Set 12 | eydhafushi
# Processing Record 20 of Set 12 | broome
# Processing Record 21 of Set 12 | cobija
# Processing Record 22 of Set 12 | axim
# Processing Record 23 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 12 | ust-kan
# Processing Record 25 of Set 12 | port lincoln
# Processing Record 26 of Set 12 | mikkeli
# Processing Record 27 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 28 of Set 12 | linqiong
# Processing Record 29 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 30 of Set 12 | antofagasta
# Processing Record 31 of Set 12 | yokadouma
# Processing Record 32 of Set 12 | fukue
# Processing Record 33 of Set 12 | ciudad bolivar
# Processing Record 34 of Set 12 | erdenet
# Processing Record 35 of Set 12 | madang
# Processing Record 36 of Set 12 | valparaiso
# Processing Record 37 of Set 12 | ucluelet
# Processing Record 38 of Set 12 | kabelvag
# Processing Record 39 of Set 12 | minna
# Processing Record 40 of Set 12 | darab
# Processing Record 41 of Set 12 | roebourne
# Processing Record 42 of Set 12 | venezuela
# Processing Record 43 of Set 12 | ketchikan
# Processing Record 44 of Set 12 | bulata
# Processing Record 45 of Set 12 | te anau
# Processing Record 46 of Set 12 | ambilobe
# Processing Record 47 of Set 12 | plonsk
# Processing Record 48 of Set 12 | the valley
# Processing Record 49 of Set 12 | roald
# Processing Record 50 of Set 12 | bereda
# Processing Record 1 of Set 13 | leshukonskoye
# Processing Record 2 of Set 13 | butwal
# Processing Record 3 of Set 13 | tres arroyos
# Processing Record 4 of Set 13 | esna
# Processing Record 5 of Set 13 | itarema
# Processing Record 6 of Set 13 | puro
# Processing Record 7 of Set 13 | henties bay
# Processing Record 8 of Set 13 | clinton
# Processing Record 9 of Set 13 | karla
# Processing Record 10 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 11 of Set 13 | adolfo lopez mateos
# Processing Record 12 of Set 13 | roros
# Processing Record 13 of Set 13 | mvomero
# Processing Record 14 of Set 13 | mookane
# Processing Record 15 of Set 13 | nanyang
# Processing Record 16 of Set 13 | ugoofaaru
# Processing Record 17 of Set 13 | shenjiamen
# Processing Record 18 of Set 13 | araouane
# Processing Record 19 of Set 13 | mahajanga
# Processing Record 20 of Set 13 | hue
# Processing Record 21 of Set 13 | algiers
# Processing Record 22 of Set 13 | liverpool
# Processing Record 23 of Set 13 | luderitz
# Processing Record 24 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 13 | vanavara
# Processing Record 26 of Set 13 | kishtwar
# Processing Record 27 of Set 13 | san andres
# Processing Record 28 of Set 13 | nemuro
# Processing Record 29 of Set 13 | acapulco
# Processing Record 30 of Set 13 | harboore
# Processing Record 31 of Set 13 | storsteinnes
# Processing Record 32 of Set 13 | trenggalek
# Processing Record 33 of Set 13 | orahovac
# Processing Record 34 of Set 13 | svetlaya
# Processing Record 35 of Set 13 | thul
# Processing Record 36 of Set 13 | inirida
# Processing Record 37 of Set 13 | bahia blanca
# Processing Record 38 of Set 13 | tezu
# Processing Record 39 of Set 13 | winslow
# Processing Record 40 of Set 13 | matamoros
# Processing Record 41 of Set 13 | pandan
# Processing Record 42 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 13 | saint-georges
# Processing Record 44 of Set 13 | makakilo city
# Processing Record 45 of Set 13 | wad madani
# Processing Record 46 of Set 13 | niquelandia
# Processing Record 47 of Set 13 | tabuk
# Processing Record 48 of Set 13 | qingan
# City not found. Skipping...
# Processing Record 49 of Set 13 | kloulklubed
# Processing Record 50 of Set 13 | camapua
# Processing Record 1 of Set 14 | peachland
# Processing Record 2 of Set 14 | tomatlan
# Processing Record 3 of Set 14 | kaita
# Processing Record 4 of Set 14 | fuerte olimpo
# Processing Record 5 of Set 14 | berdigestyakh
# Processing Record 6 of Set 14 | gomel
# Processing Record 7 of Set 14 | fethiye
# Processing Record 8 of Set 14 | wanning
# Processing Record 9 of Set 14 | dimbokro
# Processing Record 10 of Set 14 | damietta
# Processing Record 11 of Set 14 | arys
# Processing Record 12 of Set 14 | dhidhdhoo
# Processing Record 13 of Set 14 | khandyga
# Processing Record 14 of Set 14 | hambantota
# Processing Record 15 of Set 14 | frontera
# Processing Record 16 of Set 14 | atar
# Processing Record 17 of Set 14 | mahina
# Processing Record 18 of Set 14 | sturgeon falls
# Processing Record 19 of Set 14 | baruun-urt
# Processing Record 20 of Set 14 | kiruna
# Processing Record 21 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 14 | yabrud
# Processing Record 23 of Set 14 | nakamura
# Processing Record 24 of Set 14 | mlimba
# Processing Record 25 of Set 14 | palana
# Processing Record 26 of Set 14 | nuuk
# Processing Record 27 of Set 14 | zhigansk
# Processing Record 28 of Set 14 | deputatskiy
# Processing Record 29 of Set 14 | henderson
# Processing Record 30 of Set 14 | manta
# Processing Record 31 of Set 14 | strezhevoy
# Processing Record 32 of Set 14 | khani
# Processing Record 33 of Set 14 | chimoio
# Processing Record 34 of Set 14 | nova zagora
# Processing Record 35 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 37 of Set 14 | margate
# Processing Record 38 of Set 14 | asau
# Processing Record 39 of Set 14 | barreirinha
# Processing Record 40 of Set 14 | the pas
# Processing Record 41 of Set 14 | goderich
# Processing Record 42 of Set 14 | troitsko-pechorsk
# Processing Record 43 of Set 14 | pacific grove
# Processing Record 44 of Set 14 | terrace
# Processing Record 45 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 14 | bad sassendorf
# Processing Record 47 of Set 14 | domoni
# Processing Record 48 of Set 14 | taunggyi
# Processing Record 49 of Set 14 | lyngdal
# Processing Record 50 of Set 14 | paso de carrasco
# Processing Record 1 of Set 15 | magistralnyy
# Processing Record 2 of Set 15 | mumford
# Processing Record 3 of Set 15 | mazarron
# Processing Record 4 of Set 15 | kahului
# Processing Record 5 of Set 15 | kotli loharan
# Processing Record 6 of Set 15 | seoni malwa
# Processing Record 7 of Set 15 | catuday
# Processing Record 8 of Set 15 | vardo
# Processing Record 9 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 15 | seda
# Processing Record 11 of Set 15 | nago
# Processing Record 12 of Set 15 | clearwater
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 658

# %%
# Convert the array of dictionaries to a Pandas DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Fort Dodge      US  42.4975  -94.1680     90.01        51           0
# 1      Babaeski      TR  41.4325   27.0931     66.09        55           0
# 2     Cape Town      ZA -33.9258   18.4232     57.90        82          10
# 3    Nouadhibou      MR  20.9310  -17.0347     69.78        88          21
# 4        Atuona      PF  -9.8000 -139.0333     77.31        72           9
# 5      Hermanus      ZA -34.4187   19.2345     51.80        82          10
# 6  Punta Arenas      CL -53.1500  -70.9167     32.11        93          75
# 7        Dikson      RU  73.5069   80.5464     42.57        76          35
# 8        Castro      BR -24.7911  -50.0119     59.05        76          40
# 9         Pevek      RU  69.7008  170.3133     33.42        86           7
#
#    Wind Speed Current Description
# 0       12.66           clear sky
# 1        4.50           clear sky
# 2        5.99           clear sky
# 3       12.66          few clouds
# 4       14.41           clear sky
# 5        5.91           clear sky
# 6        2.30       broken clouds
# 7        9.82    scattered clouds
# 8        3.42    scattered clouds
# 9       13.27           clear sky

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
